# %%
import pandas as pd
import ast

# %%
# Read the csv file first
df = pd.read_csv('IT_List_2.csv')

# %%
# Checking data frame's content
df.head()
# Out:
#                                            apply_url  \
# 0      https://www.linkedin.com/job-apply/3811594566
# 1  https://ukcareers.hdi.global/Careers_Portal/Ap...
# 2  https://ukcareers.hdi.global/Careers_Portal/Ap...
# 3  https://ukcareers.hdi.global/Careers_Portal/Ap...
# 4      https://www.linkedin.com/job-apply/3813457721
#
#                         category             city  civility     company_city  \
# 0  IT Services and IT Consulting         Plymouth       NaN         Plymouth
# 1                      Insurance         Hannover  Monsieur         Hannover
# 2                      Insurance         Hannover    Madame         Hannover
# 3                      Insurance         Hannover  Monsieur         Hannover
# 4             Telecommunications  Shoreham by Sea  Monsieur  Shoreham by Sea
#
#   company_country                             company_crunchbase_url  \
# 0              GB                                                NaN
# 1              DE                                                NaN
# 2              DE                                                NaN
# 3              DE                                                NaN
# 4              GB  https://www.crunchbase.com/organization/focus-...
#
#                                  company_description      company_domain  \
# 0  Delt is an innovative shared services partners...  deltservices.co.uk
# 1  Companies from the trading, manufacturing and ...          hdi.global
# 2  Companies from the trading, manufacturing and ...          hdi.global
# 3  Companies from the trading, manufacturing and ...          hdi.global
# 4  Welcome to Focus Group.  Established in 2003, ...    focusgroup.co.uk
#
#    company_employee_metrics  ...  tenure_end tenure_length tenure_start  \
# 0                       NaN  ...     02/2024  0 yrs 10 mos      05/2023
# 1                       NaN  ...     02/2024   2 yrs 8 mos      07/2021
# 2                       NaN  ...     02/2024   0 yrs 1 mos      02/2024
# 3                       NaN  ...     02/2024   2 yrs 1 mos      02/2022
# 4                       NaN  ...     02/2024   1 yrs 8 mos      07/2022
#
#                                       title  twitter       type  \
# 0                   Senior Desktop Engineer      NaN  Full-time
# 1                   Senior Desktop Engineer      NaN  Full-time
# 2                   Senior Desktop Engineer      NaN  Full-time
# 3                   Senior Desktop Engineer      NaN  Full-time
# 4  Service Operations Director (1 year FTC)      NaN   Contract
#
#                    updated_at  viewed                        website  \
# 0  2024-02-21T09:07:01.244000   False  http://www.deltservices.co.uk
# 1  2024-02-21T09:07:21.287000   False          http://www.hdi.global
# 2  2024-02-21T09:07:21.287000   False          http://www.hdi.global
# 3  2024-02-21T09:07:21.287000   False          http://www.hdi.global
# 4  2024-02-21T09:07:31.264000   False       https://focusgroup.co.uk
#
#   year_founded
# 0       2014.0
# 1       1903.0
# 2       1903.0
# 3       1903.0
# 4       2003.0
#
# [5 rows x 157 columns]

# %%
df['sales_navigator_company_id'].head()
# Out:
# 0     9253115.0
# 1    10393861.0
# 2    10393861.0
# 3    10393861.0
# 4      806245.0
# Name: sales_navigator_company_id, dtype: float64

# %%
df['company_id'].head()
# Out:
# 0     9253115.0
# 1    10393861.0
# 2    10393861.0
# 3    10393861.0
# 4      806245.0
# Name: company_id, dtype: float64

# %%
df['meta']
# Out:
# 0      {"apply_url": "https://www.linkedin.com/job-ap...
# 1      {"apply_url": "https://ukcareers.hdi.global/Ca...
# 2      {"apply_url": "https://ukcareers.hdi.global/Ca...
# 3      {"apply_url": "https://ukcareers.hdi.global/Ca...
# 4      {"apply_url": "https://www.linkedin.com/job-ap...
#                              ...
# 141    {"apply_url": "https://www.roberthalf.com/gb/e...
# 142    {"apply_url": "https://www.roberthalf.com/gb/e...
# 143    {"apply_url": "https://www.roberthalf.com/gb/e...
# 144    {"apply_url": "https://www.roberthalf.com/gb/e...
# 145    {"apply_url": "https://www.roberthalf.com/gb/e...
# Name: meta, Length: 146, dtype: object

# %%
# Display Columns
df.columns
# Out:
# Index(['apply_url', 'category', 'city', 'civility', 'company_city',
#        'company_country', 'company_crunchbase_url', 'company_description',
#        'company_domain', 'company_employee_metrics',
#        ...
#        'tenure_end', 'tenure_length', 'tenure_start', 'title', 'twitter',
#        'type', 'updated_at', 'viewed', 'website', 'year_founded'],
#       dtype='object', length=157)

# %%
df['industry']
# Out:
# 0      IT Services and IT Consulting
# 1                          Insurance
# 2                          Insurance
# 3                          Insurance
# 4                 Telecommunications
#                    ...
# 141          Staffing and Recruiting
# 142          Staffing and Recruiting
# 143          Staffing and Recruiting
# 144          Staffing and Recruiting
# 145          Staffing and Recruiting
# Name: industry, Length: 146, dtype: object

# %%
# Handpick important columns
df1_columns = ['job_title', 'full_name', 'linkedin_profile_id', 'linkedin_profile_url', 'location', 'sales_navigator_company_id',
              'tenure_length', 'company_id', 'company_name', "industry"]

# %%
cleaned_df1 = df[df1_columns]

# %%
cleaned_df1['company_id'].isnull
# Out:
# <bound method Series.isnull of 0       9253115.0
# 1      10393861.0
# 2      10393861.0
# 3      10393861.0
# 4        806245.0
#           ...
# 141        1681.0
# 142        1681.0
# 143        1681.0
# 144        1681.0
# 145        1681.0
# Name: company_id, Length: 146, dtype: float64>

# %%
cleaned_df1.loc[:, 'company_id'] = cleaned_df1['company_id'].fillna(0).astype(int).astype(str)
# Out:
# /tmp/ipykernel_329/3687494531.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['9253115' '10393861' '10393861' '10393861' '806245' '806245' '806245'
#  '806245' '806245' '18171321' '1373' '1373' '1373' '1373' '0' '108365'
#  '108365' '2409899' '3653845' '3653845' '3653845' '3653845' '3653845'
#  '274161' '274161' '274161' '274161' '274161' '274161' '274161' '274161'
#  '1207' '1207' '1207' '1207' '1207' '3549' '3549' '3549' '3549' '3549'
#  '1031903' '150566' '150566' '150566' '150566' '23682' '5205246' '5205246'
#  '5205246' '5205246' '1211186' '1211186' '0' '0' '1211186' '7253' '7253'
#  '7253' '7253' '7253' '585010' '585010' '585010' '6633045' '209557'
#  '209557' '209557' '209557' '209557' '4451' '4451' '4451' '4451' '4451'
#  '3269' '3269' '3269' '3269' '3269' '8217' '23042' '23042' '3514275'
#  '6633045' '0' '7601' '7601' '7601' '7601' '7601' '1614' '1550138'
#  '1550138' '1550138' '1550138' '67849' '67849' '67849' '27022839' '0'
#  '34221877' '1104359' '1104359' '1104359' '0' '1104359' '0' '3993' '3993'
#  '0' '3993' '3476' '3476' '3476' '0' '3476' '28672826' '10304623'
#  '10304623' '0' '10304623' '18171321' '36404' '36404' '36404' '36404'
#  '18171321' '0' '18171321' '1681' '1681' '1681' '1681' '1681' '1681'
#  '1681' '1681' '1681' '1681' '1681' '1681' '1681' '1681' '1681' '1681']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   cleaned_df1.loc[:, 'company_id'] = cleaned_df1['company_id'].fillna(0).astype(int).astype(str)

# %%
cleaned_df1['company_id']
# Out:
# 0       9253115
# 1      10393861
# 2      10393861
# 3      10393861
# 4        806245
#          ...
# 141        1681
# 142        1681
# 143        1681
# 144        1681
# 145        1681
# Name: company_id, Length: 146, dtype: object

# %%
# Extracting the metadata from the 'meta' column
df['meta'] = df['meta'].apply(ast.literal_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_329/3088912916.py in <module>
#       1 # Extracting the metadata from the 'meta' column
# ----> 2 df['meta'] = df['meta'].apply(ast.literal_eval)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4902             args=args,
#    4903             kwargs=kwargs,
# -> 4904         ).apply()
#    4905
#    4906     def _reindex_indexer(
#
# ~/.local/lib/python3.10/site-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# ~/.local/lib/python3.10/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# ~/.local/lib/python3.10/site-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /usr/lib/python3.10/ast.py in literal_eval(node_or_string)
#     108                     return left - right
#     109         return _convert_signed_num(node)
# --> 110     return _convert(node_or_string)
#     111
#     112
#
# /usr/lib/python3.10/ast.py in _convert(node)
#     107                 else:
#     108                     return left - right
# --> 109         return _convert_signed_num(node)
#     110     return _convert(node_or_string)
#     111
#
# /usr/lib/python3.10/ast.py in _convert_signed_num(node)
#      81             else:
#      82                 return - operand
# ---> 83         return _convert_num(node)
#      84     def _convert(node):
#      85         if isinstance(node, Constant):
#
# /usr/lib/python3.10/ast.py in _convert_num(node)
#      72     def _convert_num(node):
#      73         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74             _raise_malformed_node(node)
#      75         return node.value
#      76     def _convert_signed_num(node):
#
# /usr/lib/python3.10/ast.py in _raise_malformed_node(node)
#      69         if lno := getattr(node, 'lineno', None):
#      70             msg += f' on line {lno}'
# ---> 71         raise ValueError(msg + f': {node!r}')
#      72     def _convert_num(node):
#      73         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
#
# ValueError: malformed node or string: {'apply_url': 'https://www.linkedin.com/job-apply/3811594566', 'category': 'IT Services and IT Consulting', 'city': 'Plymouth', 'company_id': '9253115', 'company_name': 'Delt Shared Services Ltd', 'company_size': '51-200', 'country': 'GB', 'crunchbase_company_url': '', 'crunchbase_url': '', 'description': 'Delt is a brilliant contradiction. A dynamic and agile private sector company with a serious conscience, that’s wholly owned by the public sector. It’s somewhere you can do the right things for the right reasons while playing a real part in a growing business. In short – we help people do amazing things. We are seeking a skilled Senior Desktop Engineer to join our End User Computing team with enterprise level experience who can hit the ground running whilst embodying the Delt values. You’ll play an instrumental role in supporting our customers and shareholders whilst being given plenty of opportunity to better your skillset and take on new challenges through our dedication to employee development. The Senior Desktop Engineer will provide enterprise support to multiple large tenants at several sites across the Southwest. The role will involve managing and administering the technology and tools used to provision and support end user devices throughout their lifecycle. This role is hybrid working, with a realistic expectation to attend the Plymouth office once a week. Job Overview: As a Senior Desktop Engineer, you will play a key role in designing, implementing, and supporting end user computing solutions for our clients. You will be responsible for ensuring the stability, security, and optimal performance of desktops, laptops, tables and mobile devices, as well as providing technical expertise to resolve complex issues. This position offers an exciting opportunity for a seasoned professional to contribute to the success of our projects and mentor junior team members. Responsibilities: Design, deploy, and maintain end user computing solutions.Provide advanced technical support.Collaborate with cross-functional teams to implement and optimise products and solutions.Evaluate and recommend hardware and software solutions to meet business requirements.Conduct regular system audits for security and performance enhancements (automation).Mentor and guide junior desktop engineers.Stay current with industry trends and emerging technologies. Requirements: Bachelor’s degree in Computer Science, Information Technology, or related field.Proven experience with device management technologies such as: Microsoft Configuration ManagerMicrosoft IntuneApple Business ManagerSamsung KnoxGoogle WorkspaceIvanti MobileIron Strong expertise in end user operating systems (Windows, Android, iOS) and applications.Excellent troubleshooting and problem-solving skills.Ability to work independently and collaboratively in a team environment.Effective communication and interpersonal skills.Relevant certifications: Microsoft Certified (Windows 10, MCP, MCTS, etc.)ITIL v3 FoundationFull UK Driving License If this sounds like you, get in touch! What do you get? Being part of a highly technical and skilled teamWork in a flexible environmentOpportunities for working from homeMobile devices providedVaried training opportunities Applications will be considered on a rolling basis so please apply early, as we reserve the right to close the advert once we have sufficient quality applications', 'domain': 'deltservices.co.uk', 'employees': '173', 'employees_count': '173', 'employees_estimate': '51-200', 'employees_range': '51-200', 'employees_url': 'https://www.linkedin.com/search/results/people/?currentCompany=%5B%22{{9253115}}%22%5D', 'extracted_at': '2024-02-21 09:25:26', 'field': '["IT"]', 'followers_count': '2854', 'founded_on': '2014', 'geographic_area': '', 'headquarters': '2 Derriford Business Park Derriford PL6 5QZ Plymouth GB', 'id': '3811594566', 'industries': '["IT Services and IT Consulting"]', 'industry': 'IT Services and ...

# %%
# Creating the columns using lambda function to each column of the metadata
metadata_cols = df['meta'].apply(lambda x: pd.Series(x))

# %%
metadata_cols['updated_at']
# Out:
# 0      2024-02-21T09:07:01.244000
# 1      2024-02-21T09:07:21.287000
# 2      2024-02-21T09:07:21.287000
# 3      2024-02-21T09:07:21.287000
# 4      2024-02-21T09:07:31.264000
#                   ...
# 141    2024-02-21T09:21:23.675000
# 142    2024-02-21T09:21:23.675000
# 143    2024-02-21T09:21:23.675000
# 144    2024-02-21T09:21:23.675000
# 145    2024-02-21T09:21:23.675000
# Name: updated_at, Length: 146, dtype: object

# %%
metadata_cols['sales_navigator_url']
# Out:
# 0       https://www.linkedin.com/sales/company/9253115
# 1      https://www.linkedin.com/sales/company/10393861
# 2      https://www.linkedin.com/sales/company/10393861
# 3      https://www.linkedin.com/sales/company/10393861
# 4        https://www.linkedin.com/sales/company/806245
#                             ...
# 141        https://www.linkedin.com/sales/company/1681
# 142        https://www.linkedin.com/sales/company/1681
# 143        https://www.linkedin.com/sales/company/1681
# 144        https://www.linkedin.com/sales/company/1681
# 145        https://www.linkedin.com/sales/company/1681
# Name: sales_navigator_url, Length: 146, dtype: object

# %%
# Handpick the important columns from the metadata
metadata_cols.columns
# Out:
# Index(['apply_url', 'category', 'city', 'company_id', 'company_name',
#        'company_size', 'country', 'crunchbase_company_url', 'crunchbase_url',
#        'description', 'domain', 'employees', 'employees_count',
#        'employees_estimate', 'employees_range', 'employees_url',
#        'extracted_at', 'field', 'followers_count', 'founded_on',
#        'geographic_area', 'headquarters', 'id', 'industries', 'industry',
#        'job_description', 'job_id', 'job_search_url', 'job_url',
#        'last_funding_currency', 'last_funding_date', 'last_funding_investors',
#        'last_funding_raised', 'last_funding_type', 'linkedin_company_id',
#        'linkedin_employees_url', 'linkedin_job_application_url',
#        'linkedin_job_id', 'linkedin_job_search_url', 'linkedin_job_url',
#        'linkedin_profile_id', 'linkedin_profile_url', 'linkedin_school_id',
#        'linkedin_url', 'location', 'locations', 'logo_url', 'name',
#        'number_employees', 'number_of_locations', 'phone', 'phones',
#        'postal_code', 'poster_full_name', 'poster_id', 'poster_profile_url',
#        'profile_full_name', 'remote_allowed', 'sales_navigator_company_url',
#        'sales_navigator_employees_url', 'sales_navigator_url', 'school_id',
#        'skills', 'specialities', 'specialties', 'start_url', 'tagline',
#        'title', 'type', 'updated_at', 'website', 'year_founded'],
#       dtype='object')

# %%
df2_columns = ['title', 'job_description', 'job_url', 'job_id', 'poster_full_name', 'poster_id', 'poster_profile_url',
              'company_id', 'number_employees']

# %%
cleaned_df2 = metadata_cols[df2_columns]

# %%
cleaned_df2['company_id']
# Out:
# 0       9253115
# 1      10393861
# 2      10393861
# 3      10393861
# 4        806245
#          ...
# 141        1681
# 142        1681
# 143        1681
# 144        1681
# 145        1681
# Name: company_id, Length: 146, dtype: object

# %%
cleaned_df2
# Out:
#                                         title  \
# 0                     Senior Desktop Engineer
# 1                     Senior Desktop Engineer
# 2                     Senior Desktop Engineer
# 3                     Senior Desktop Engineer
# 4    Service Operations Director (1 year FTC)
# ..                                        ...
# 141                                IT Manager
# 142                                IT Manager
# 143                                IT Manager
# 144                                IT Manager
# 145                                IT Manager
#
#                                        job_description  \
# 0    Delt is a brilliant contradiction. A dynamic a...
# 1    HDI Global is part of the Talanx Group, one of...
# 2    HDI Global is part of the Talanx Group, one of...
# 3    HDI Global is part of the Talanx Group, one of...
# 4    Service Operations Director (1 year Fixed Term...
# ..                                                 ...
# 141  Job Title: IT Manager - Global Cable Manufactu...
# 142  IT Manager - Monday to Friday 8.30am to 5pm - ...
# 143  IT Manager - Monday to Friday 8.30am to 5pm - ...
# 144  IT Manager - Monday to Friday 8.30am to 5pm - ...
# 145  IT Manager - Monday to Friday 8.30am to 5pm - ...
#
#                                                job_url      job_id  \
# 0    https://www.linkedin.com/jobs/view/3811594566/...  3811594566
# 1    https://www.linkedin.com/jobs/view/3824843209/...  3824843209
# 2    https://www.linkedin.com/jobs/view/3824843209/...  3824843209
# 3    https://www.linkedin.com/jobs/view/3824843209/...  3824843209
# 4    https://www.linkedin.com/jobs/view/3813457721/...  3813457721
# ..                                                 ...         ...
# 141  https://www.linkedin.com/jobs/view/3819468291/...  3819468291
# 142  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
# 143  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
# 144  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
# 145  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
#
#      poster_full_name                                poster_id  \
# 0        Neil Stevens  ACoAADkzllsBOdOWQmopYVApEbdM55OA1IrEoBc
# 1
# 2
# 3
# 4    Jonathan Hassall  ACoAAAAJXgwBs8FQISRrislupKThBJJB4I82_rg
# ..                ...                                      ...
# 141
# 142
# 143
# 144
# 145
#
#                                     poster_profile_url company_id  \
# 0    https://www.linkedin.com/in/neil-stevens-73748...    9253115
# 1                                                        10393861
# 2                                                        10393861
# 3                                                        10393861
# 4          https://www.linkedin.com/in/jonathanhassall     806245
# ..                                                 ...        ...
# 141                                                          1681
# 142                                                          1681
# 143                                                          1681
# 144                                                          1681
# 145                                                          1681
#
#     number_employees
# 0                173
# 1               2951
# 2               2951
# 3               2951
# 4                723
# ..               ...
# 141            29053
# 142            29053
# 143            29053
# 144            29053
# 145            29053
#
# [146 rows x 9 columns]

# %%
cleaned_df1
# Out:
#                                              job_title            full_name  \
# 0                                  Head Of Hr Services      Julie Blackmore
# 1                Director Of Operations - Uk & Ireland       Arvind Drubhra
# 2                        Finance & Operations Director           Alison Fox
# 3               Director Of Engineering & Construction        Richard Beeby
# 4                      Director Of Business Operations  Edward Rodney-Smith
# ..                                                 ...                  ...
# 141                     Senior Director, Hr Technology      Caitlin Schmidt
# 142  Market Director - Interim - Finance And Accoun...     Hannah Szymanski
# 143             Senior Director Of Operational Support      Charlotte Booth
# 144              Director Hr Uk, Ireland & Middle East         Vicky Austin
# 145                     Senior Director, Hr Technology      Caitlin Schmidt
#
#      linkedin_profile_id                               linkedin_profile_url  \
# 0              181327871  https://www.linkedin.com/in/ACwAAArO1_8BOhV5ta...
# 1               22415604  https://www.linkedin.com/in/ACwAAAFWCPQB-cxvV_...
# 2              107491154  https://www.linkedin.com/in/ACwAAAZoL1IBMNhpRK...
# 3              523796775  https://www.linkedin.com/in/ACwAAB84gScBk5tzcE...
# 4               16502900  https://www.linkedin.com/in/ACwAAAD70HQBljAnNR...
# ..                   ...                                                ...
# 141             90341404  https://www.linkedin.com/in/ACwAAAVigBwBjxNzf-...
# 142            121328811  https://www.linkedin.com/in/ACwAAAc7VKsBTiD6Wj...
# 143             77404080  https://www.linkedin.com/in/ACwAAASdF7ABgCFJ5W...
# 144             28707367  https://www.linkedin.com/in/ACwAAAG2CicB485WCV...
# 145             90341404  https://www.linkedin.com/in/ACwAAAVigBwBjxNzf-...
#
#                                     location  sales_navigator_company_id  \
# 0            London, England, United Kingdom                   9253115.0
# 1            London, England, United Kingdom                  10393861.0
# 2            London, England, United Kingdom                  10393861.0
# 3    City of London, England, United Kingdom                  10393861.0
# 4            London, England, United Kingdom                    806245.0
# ..                                       ...                         ...
# 141          London, England, United Kingdom                      1681.0
# 142          London, England, United Kingdom                      1681.0
# 143                           United Kingdom                      1681.0
# 144   West Midlands, England, United Kingdom                      1681.0
# 145          London, England, United Kingdom                      1681.0
#
#     tenure_length company_id              company_name  \
# 0    0 yrs 10 mos    9253115  Delt Shared Services Ltd
# 1     2 yrs 8 mos   10393861             Hdi Global Se
# 2     0 yrs 1 mos   10393861             Hdi Global Se
# 3     2 yrs 1 mos   10393861             Hdi Global Se
# 4     1 yrs 8 mos     806245               Focus Group
# ..            ...        ...                       ...
# 141   3 yrs 4 mos       1681               Robert Half
# 142   0 yrs 7 mos       1681               Robert Half
# 143   4 yrs 7 mos       1681               Robert Half
# 144   2 yrs 1 mos       1681               Robert Half
# 145   3 yrs 4 mos       1681               Robert Half
#
#                           industry
# 0    IT Services and IT Consulting
# 1                        Insurance
# 2                        Insurance
# 3                        Insurance
# 4               Telecommunications
# ..                             ...
# 141        Staffing and Recruiting
# 142        Staffing and Recruiting
# 143        Staffing and Recruiting
# 144        Staffing and Recruiting
# 145        Staffing and Recruiting
#
# [146 rows x 10 columns]

# %%
merged_df = pd.merge(cleaned_df2, cleaned_df1, on="company_id")

# %%
merged_df
# Out:
#                        title  \
# 0    Senior Desktop Engineer
# 1    Senior Desktop Engineer
# 2    Senior Desktop Engineer
# 3    Senior Desktop Engineer
# 4    Senior Desktop Engineer
# ..                       ...
# 771               IT Manager
# 772               IT Manager
# 773               IT Manager
# 774               IT Manager
# 775               IT Manager
#
#                                        job_description  \
# 0    Delt is a brilliant contradiction. A dynamic a...
# 1    HDI Global is part of the Talanx Group, one of...
# 2    HDI Global is part of the Talanx Group, one of...
# 3    HDI Global is part of the Talanx Group, one of...
# 4    HDI Global is part of the Talanx Group, one of...
# ..                                                 ...
# 771  IT Manager - Monday to Friday 8.30am to 5pm - ...
# 772  IT Manager - Monday to Friday 8.30am to 5pm - ...
# 773  IT Manager - Monday to Friday 8.30am to 5pm - ...
# 774  IT Manager - Monday to Friday 8.30am to 5pm - ...
# 775  IT Manager - Monday to Friday 8.30am to 5pm - ...
#
#                                                job_url      job_id  \
# 0    https://www.linkedin.com/jobs/view/3811594566/...  3811594566
# 1    https://www.linkedin.com/jobs/view/3824843209/...  3824843209
# 2    https://www.linkedin.com/jobs/view/3824843209/...  3824843209
# 3    https://www.linkedin.com/jobs/view/3824843209/...  3824843209
# 4    https://www.linkedin.com/jobs/view/3824843209/...  3824843209
# ..                                                 ...         ...
# 771  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
# 772  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
# 773  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
# 774  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
# 775  https://www.linkedin.com/jobs/view/3813666573/...  3813666573
#
#     poster_full_name                                poster_id  \
# 0       Neil Stevens  ACoAADkzllsBOdOWQmopYVApEbdM55OA1IrEoBc
# 1
# 2
# 3
# 4
# ..               ...                                      ...
# 771
# 772
# 773
# 774
# 775
#
#                                     poster_profile_url company_id  \
# 0    https://www.linkedin.com/in/neil-stevens-73748...    9253115
# 1                                                        10393861
# 2                                                        10393861
# 3                                                        10393861
# 4                                                        10393861
# ..                                                 ...        ...
# 771                                                          1681
# 772                                                          1681
# 773                                                          1681
# 774                                                          1681
# 775                                                          1681
#
#     number_employees                                          job_title  \
# 0                173                                Head Of Hr Services
# 1               2951              Director Of Operations - Uk & Ireland
# 2               2951                      Finance & Operations Director
# 3               2951             Director Of Engineering & Construction
# 4               2951              Director Of Operations - Uk & Ireland
# ..               ...                                                ...
# 771            29053                     Senior Director, Hr Technology
# 772            29053  Market Director - Interim - Finance And Accoun...
# 773            29053             Senior Director Of Operational Support
# 774            29053              Director Hr Uk, Ireland & Middle East
# 775            29053                     Senior Director, Hr Technology
#
#             full_name  linkedin_profile_id  \
# 0     Julie Blackmore            181327871
# 1      Arvind Drubhra             22415604
# 2          Alison Fox            107491154
# 3       Richard Beeby            523796775
# 4      Arvind Drubhra             22415604
# ..                ...                  ...
# 771   Caitlin Schmidt             90341404
# 772  Hannah Szymanski            121328811
# 773   Charlotte Booth             77404080
# 774      Vicky Austin             28707367
# 775   Caitlin Schmidt             90341404
#
#                                   linkedin_profile_url  \
# 0    https://www.linkedin.com/in/ACwAAArO1_8BOhV5ta...
# 1    https://www.linkedin.com/in/ACwAAAFWCPQB-cxvV_...
# 2    https://www.linkedin.com/in/ACwAAAZoL1IBMNhpRK...
# 3    https://www.linkedin.com/in/ACwAAB84gScBk5tzcE...
# 4    https://www.linkedin.com/in/ACwAAAFWCPQB-cxvV_...
# ..                                                 ...
# 771  https://www.linkedin.com/in/ACwAAAVigBwBjxNzf-...
# 772  https://www.linkedin.com/in/ACwAAAc7VKsBTiD6Wj...
# 773  https://www.linkedin.com/in/ACwAAASdF7ABgCFJ5W...
# 774  https://www.linkedin.com/in/ACwAAAG2CicB485WCV...
# 775  https://www.linkedin.com/in/ACwAAAVigBwBjxNzf-...
#
#                                     location  sales_navigator_company_id  \
# 0            London, England, United Kingdom                   9253115.0
# 1            London, England, United Kingdom                  10393861.0
# 2            London, England, United Kingdom                  10393861.0
# 3    City of London, England, United Kingdom                  10393861.0
# 4            London, England, United Kingdom                  10393861.0
# ..                                       ...                         ...
# 771          London, England, United Kingdom                      1681.0
# 772          London, England, United Kingdom                      1681.0
# 773                           United Kingdom                      1681.0
# 774   West Midlands, England, United Kingdom                      1681.0
# 775          London, England, United Kingdom                      1681.0
#
#     tenure_length              company_name                       industry
# 0    0 yrs 10 mos  Delt Shared Services Ltd  IT Services and IT Consulting
# 1     2 yrs 8 mos             Hdi Global Se                      Insurance
# 2     0 yrs 1 mos             Hdi Global Se                      Insurance
# 3     2 yrs 1 mos             Hdi Global Se                      Insurance
# 4     2 yrs 8 mos             Hdi Global Se                      Insurance
# ..            ...                       ...                            ...
# 771   3 yrs 4 mos               Robert Half        Staffing and Recruiting
# 772   0 yrs 7 mos               Robert Half        Staffing and Recruiting
# 773   4 yrs 7 mos               Robert Half        Staffing and Recruiting
# 774   2 yrs 1 mos               Robert Half        Staffing and Recruiting
# 775   3 yrs 4 mos               Robert Half        Staffing and Recruiting
#
# [776 rows x 18 columns]

# %%
merged_df.to_csv("ITScrape - 2nd List.csv")
